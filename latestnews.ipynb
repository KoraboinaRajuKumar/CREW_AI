# %%
! pip install crewai crewai_tools langchain langchain_community langchain_openai

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import ChatOpenAI
OPENAI_API-KEY="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"
llm=ChatOpenAI(temperature=0, model="gpt-4o-mini")
# Out:
# C:\Users\rajut\AppData\Local\Temp\ipykernel_30432\4163322192.py:3: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm=ChatOpenAI(temperature=0, model="gpt-4o-mini")
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[3], line 3
#       1 from langchain.chat_models import ChatOpenAI
#       2 os.environ["OPENAI_API-KEY"]="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"
# ----> 3 llm=ChatOpenAI(temperature=0, model="gpt-4o-mini")
#
# ...
